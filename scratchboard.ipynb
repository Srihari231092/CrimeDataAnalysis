# %%
import os
import time
import pandas as pd
import numpy as np
import datetime

from DataExtractor import DataExtractor
from CrimeStudy import CrimeStudy
from VizTools import *

# %%
_path = "/media/srihari/OS/Users/SSrih/OneDrive/UChicago/DEP/Project/data/Crime/"
file_name = "Crimes_-_2001_to_present.csv"

# Load the data
data_extractor = DataExtractor()
read_start_time = time.time()
data = data_extractor.read_csv(fpath=os.path.join(_path, file_name), nrows_to_read=1000)
read_end_time = time.time()

print("Total read time : ", read_end_time - read_start_time)

print(" Shape :", data.shape)
print(" Columns :", data.columns)
# Out:
# Total read time :  0.013983011245727539
#  Shape : (1000, 22)
#  Columns : Index(['ID', 'Case Number', 'Date', 'Block', 'IUCR', 'Primary Type',
#        'Description', 'Location Description', 'Arrest', 'Domestic', 'Beat',
#        'District', 'Ward', 'Community Area', 'FBI Code', 'X Coordinate',
#        'Y Coordinate', 'Year', 'Updated On', 'Latitude', 'Longitude',
#        'Location'],
#       dtype='object')

# %%
# Convert the Date column into a datetime type
data['Date'] = pd.to_datetime(data['Date'])

# %%
data.sort_values(by='Date', inplace=True)

# %%
# Filter the rows based on the date
start_date = pd.to_datetime(datetime.date(year=2001, month=1, day=1))
end_date = pd.to_datetime(datetime.date(year=2019, month=1, day=1))

data = data[(data['Date'] > start_date) & (data['Date'] < end_date)]

print(" Shape :", data.shape)
# Out:
#  Shape : (1000, 22)

# %%
print(data)
# out_path = str(start_date.year) + "_" + str(end_date.year) + ".csv"
# out_path = os.path.join(_path, out_path)
# print(out_path)
# Out:
#            ID Case Number                Date  \
# 125   4755307    HM367521 2002-01-23 00:00:00
# 638      4756    HP587530 2008-09-22 23:24:00
# 958  10002447    HY191733 2014-01-01 00:01:00
# 406  10001210    HY190787 2014-01-02 09:00:00
# 769  10001693    HY191147 2014-03-15 00:01:00
# 248  10000845    HY190514 2014-03-15 09:00:00
# 193  10000701    HY190349 2014-06-20 09:00:00
# 539  10001392    HY190410 2014-08-06 10:00:00
# 21   10581023    HZ329792 2014-09-01 08:00:00
# 460  10001288    HY190681 2014-09-01 14:00:00
# 379  10001170    HY190664 2014-10-01 07:00:00
# 363  10001141    HY190686 2014-10-07 14:00:00
# 310  10001003    HY190542 2014-10-20 08:00:00
# 538  10001391    HY190765 2014-11-01 02:00:00
# 696  10001595    HY191041 2014-11-02 05:57:00
# 879  10002193    HY191510 2014-11-03 12:00:00
# 150  10000517    HY190259 2014-11-15 12:00:00
# 901  10002303    HY191626 2014-12-02 08:00:00
# 420  10001230    HY190700 2014-12-03 12:00:00
# ...
